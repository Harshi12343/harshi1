# %% [markdown]
# <a href="https://colab.research.google.com/github/Harshi12343/harshi1/blob/main/Welcome_To_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn import linear_model
from sklearn.metrics import mean_squared_error,mean_absolute_error
df=pd.read_csv('/content/Book1.csv')
print(df)
df.info()
print(df.isnull().sum())
print(df.head())
plt.scatter(df.Built_up_area,df.Rent,color='red',marker='*')
plt.xlabel('Built_up_area')
plt.ylabel('Rent')
plt.title('Scatterplot')
plt.show()
x=df.drop('Rent',axis=1)
print(x)
y=df.Rent
print(y)
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.33,random_state=42)
print("x_train shape:",x_train.shape)
print("x_test shape:",x_test.shape)
print("y_train shape:",y_train.shape)
print("y_test shape:",y_test.shape)
reg=linear_model.LinearRegression()
reg.fit(x,y)
y_pred=reg.predict(x_test)
print(reg.predict([[65,0,0]]))
print(reg.coef_)
print(reg.intercept_)
z=9.7900215*650+1128.879253617697
print(z)
train_score=reg.score(x_train,y_train)
test_score=reg.score(x_test,y_test)
print("Train score(R-Squared):",train_score)
print("Test score(R-Squared):",test_score)
mse=mean_squared_error(y_test,y_pred)
mae=mean_absolute_error(y_test,y_pred)
print("Mean Squared Error:",mse)
print("Mean Absolute Error:",mae)
# Out:
#     Built_up_area   Rent  PTRATIO    MEDV
# 0           6.575   4.98     15.3  504000
# 1           6.421   9.14     17.8  453600
# 2           7.185   4.03     17.8  728700
# 3           6.998   2.94     18.7  701400
# 4           7.147   5.33     18.7  760200
# ..            ...    ...      ...     ...
# 94          6.249  10.59     18.2  432600
# 95          6.625   6.65     18.0  596400
# 96          6.163  11.34     18.0  449400
# 97          8.069   4.21     18.0  812700
# 98          7.820   3.57     18.0  919800
#
# [99 rows x 4 columns]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99 entries, 0 to 98
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Built_up_area  99 non-null     float64
#  1   Rent           99 non-null     float64
#  2   PTRATIO        99 non-null     float64
#  3   MEDV           99 non-null     int64
# dtypes: float64(3), int64(1)
# memory usage: 3.2 KB
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
df=pd.read_csv('/content/breast-cancer.csv')
print(df)
print(df.info())
print(df.isnull().sum())
print(df.describe())
print(df.columns)
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
df['diagnosis']=le.fit_transform(df['diagnosis'])
print(df['diagnosis'])
x=df.drop('diagnosis',axis=1)
print(x)
y=df['diagnosis']
print(y)
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.23,random_state=0)
print("x_train shape:",x_train.shape)
print("x_test shape:",x_test.shape)
print("y_train shape:",y_train.shape)
print("y_test shape:",y_test.shape)
from sklearn.tree import DecisionTreeClassifier
model=DecisionTreeClassifier()
model.fit(x_train,y_train)
train_accuracy=model.score(x_train,y_train)
print("Train Accuracy:",train_accuracy)
test_accuracy=model.score(x_test,y_test)
print("Test Accuracy:",test_accuracy)
# Out:
#            id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0      842302         M        17.99         10.38          122.80     1001.0
# 1      842517         M        20.57         17.77          132.90     1326.0
# 2    84300903         M        19.69         21.25          130.00     1203.0
# 3    84348301         M        11.42         20.38           77.58      386.1
# 4    84358402         M        20.29         14.34          135.10     1297.0
# ..        ...       ...          ...           ...             ...        ...
# 564    926424         M        21.56         22.39          142.00     1479.0
# 565    926682         M        20.13         28.25          131.20     1261.0
# 566    926954         M        16.60         28.08          108.30      858.1
# 567    927241         M        20.60         29.33          140.10     1265.0
# 568     92751         B         7.76         24.54           47.92      181.0
#
# ...
